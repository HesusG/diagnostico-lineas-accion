# %% [markdown]
# <a href="https://colab.research.google.com/github/HesusG/diagnostico-lineas-accion/blob/main/Semana4/ejercicios_extra/practica_dashboard_teleton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica Extra: Dashboard Ejecutivo - Fundación Teletón
#
# **Objetivo:** Crear un dashboard ejecutivo completo para presentar resultados clave a la Junta Directiva de Fundación Teletón.
#
# **Competencia:** SCD0105.B - Gráficos Dinámicos
#
# **Tiempo estimado:** 90-120 minutos
#
# ---
#
# ## Contexto
#
# La Junta Directiva de Fundación Teletón necesita un dashboard ejecutivo que presente:
# 1. Estado general de satisfacción de benefactores
# 2. Identificación de áreas de oportunidad
# 3. Comparaciones entre segmentos
# 4. Recomendaciones accionables
#
# **Criterios de éxito:**
# - Dashboard claro y profesional
# - Uso de paleta Teletón
# - Insights textuales en cada sección
# - Exportable para presentación

# %% [markdown]
# ## Parte 0: Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Paleta Teletón
COLORES = {'amarillo': '#F7C600', 'morado': '#4B1F76', 'verde': '#2ECC71', 'rojo': '#E74C3C'}
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
# %matplotlib inline

# %%
# Cargar datos
df = pd.read_csv('https://raw.githubusercontent.com/HesusG/diagnostico-lineas-accion/main/Semana4/datos/teleton_benefactores.csv')
print(f"Dataset: {df.shape[0]} benefactores")
df.head()

# %% [markdown]
# ---
#
# ## Sección 1: KPIs Ejecutivos (20 puntos)
#
# Crea una visualización de 4 KPIs principales usando scorecards.
#
# **KPIs requeridos:**
# 1. Satisfacción General (promedio)
# 2. Net Promoter Score (% promotores - % detractores)
# 3. Tasa de Retención (%)
# 4. Índice de Calidad de Servicio (promedio)

# %%
# TU CÓDIGO AQUÍ: Calcular KPIs y crear visualización

# %% [markdown]
# **📝 Insight:** [Escribe 2-3 líneas interpretando los KPIs]

# %% [markdown]
# ---
#
# ## Sección 2: Análisis de Segmentos (25 puntos)
#
# Crea dos visualizaciones que comparen:
#
# **a) Satisfacción por Giro Empresarial (Top 8)**
# - Gráfico de barras horizontal
# - Ordenado de mayor a menor
# - Color morado Teletón
#
# **b) NPS por Canal de Donación**
# - Gráfico de barras vertical
# - Colores según nivel (verde > 50, amarillo 0-50, rojo < 0)

# %%
# TU CÓDIGO AQUÍ: Gráfico a) Satisfacción por Giro

# %%
# TU CÓDIGO AQUÍ: Gráfico b) NPS por Canal

# %% [markdown]
# **📝 Insights:**
# - [¿Qué giros tienen mayor satisfacción?]
# - [¿Qué canales necesitan mejora?]
# - [¿Qué patrones observas?]

# %% [markdown]
# ---
#
# ## Sección 3: Distribución y Outliers (25 puntos)
#
# Crea visualizaciones que muestren:
#
# **a) Distribución de Satisfacción por Segmento de Antigüedad**
# - Boxplot con stripplot superpuesto
# - Identifica outliers visualmente
#
# **b) Relación entre Antigüedad y Compromiso Futuro**
# - Scatter plot
# - Línea de tendencia
# - Interpreta la correlación

# %%
# TU CÓDIGO AQUÍ: Boxplot de satisfacción por antigüedad

# %%
# TU CÓDIGO AQUÍ: Scatter plot antigüedad vs compromiso

# %% [markdown]
# **📝 Insights:**
# - [¿Qué segmento tiene mayor variabilidad?]
# - [¿Hay outliers preocupantes?]
# - [¿La antigüedad predice compromiso?]

# %% [markdown]
# ---
#
# ## Sección 4: Análisis Geográfico (15 puntos)
#
# Crea una visualización que muestre:
#
# **Top 10 Estados por Cantidad de Benefactores**
# - Barras horizontales
# - Anotaciones con cantidad y % del total
# - Color azul Teletón

# %%
# TU CÓDIGO AQUÍ: Análisis geográfico

# %% [markdown]
# **📝 Insight:** [¿Hay concentración geográfica? ¿Qué implica esto?]

# %% [markdown]
# ---
#
# ## Sección 5: Dashboard Integrado (15 puntos)
#
# Crea un dashboard de 1 página que integre las visualizaciones más importantes.
#
# **Estructura sugerida:**
# ```
# ┌────────────────────────────────┐
# │  TÍTULO + 4 KPIs (Row 1)       │
# ├──────────────┬─────────────────┤
# │ Gráfico 1    │ Gráfico 2       │ (Row 2)
# ├──────────────┴─────────────────┤
# │  Gráfico Principal (Row 3)     │
# └────────────────────────────────┘
# ```

# %%
# TU CÓDIGO AQUÍ: Dashboard integrado usando subplots

# %% [markdown]
# ---
#
# ## Entregable Final: Recomendaciones Ejecutivas
#
# Basándote en todas las visualizaciones, escribe 3 recomendaciones accionables para la Junta Directiva.
#
# **Formato:**
# 1. **Recomendación:** [Acción específica]
#    - **Justificación:** [Insight de datos que la respalda]
#    - **Impacto esperado:** [Resultado anticipado]
#    - **Prioridad:** [Alta/Media/Baja]
#
# ---
#
# ### Recomendación 1:
# [TU RESPUESTA]
#
# ### Recomendación 2:
# [TU RESPUESTA]
#
# ### Recomendación 3:
# [TU RESPUESTA]
#
# ---

# %% [markdown]
# ## Checklist de Entrega
#
# - [ ] 4 KPIs calculados y visualizados
# - [ ] Análisis de segmentos completo
# - [ ] Visualizaciones de distribución
# - [ ] Análisis geográfico
# - [ ] Dashboard integrado
# - [ ] 3 recomendaciones ejecutivas
# - [ ] Todos los gráficos usan paleta Teletón
# - [ ] Insights textuales en cada sección
#
# **¡Éxito con tu dashboard! 💛📊**

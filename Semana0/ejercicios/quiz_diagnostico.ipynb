# %% [markdown]
# <a href="https://colab.research.google.com/github/HesusG/diagnostico-lineas-accion/blob/main/Semana0/ejercicios/quiz_diagnostico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📝 Quiz Diagnóstico - Semana 0
#
# **Curso:** CD2001B - Diagnóstico para Líneas de Acción
# **Objetivo:** Evaluar tu nivel actual en herramientas y conceptos básicos
# **Tiempo estimado:** 30-45 minutos
# **Puntuación:** 100 puntos totales
#
# ---
#
# ## 🎯 Propósito de Este Quiz
#
# Este quiz **NO es una calificación formal**. Su propósito es:
#
# 1. ✅ **Autoevaluación:** Identificar qué áreas necesitas reforzar
# 2. ✅ **Diagnóstico:** Ayudar al profesor a adaptar el ritmo del curso
# 3. ✅ **Orientación:** Sugerir recursos adicionales personalizados
#
# **Responde honestamente.** Si no sabes algo, ¡está bien! Para eso está el curso.
#
# ---
#
# ## 📋 Instrucciones
#
# 1. Lee cada pregunta cuidadosamente
# 2. Marca tu respuesta modificando el código o escribiendo en la celda
# 3. Al final, ejecuta la celda de autoevaluación
# 4. Revisa las áreas donde obtuviste menor puntaje
# 5. NO uses IA para responder (¡es un diagnóstico de TU nivel actual!)
#
# ---

# %% [markdown]
# ## Sección 1: Python Básico (25 puntos)
#
# ### Pregunta 1.1 (5 puntos)
#
# **¿Cuál es el tipo de dato correcto para cada uno de estos valores?**
#
# Marca la respuesta correcta editando la variable `respuesta_1_1`:

# %%
# Valores:
# a) "Hola mundo"
# b) 42
# c) 3.14
# d) True

# Opciones: "string", "int", "float", "boolean"

respuesta_1_1 = {
    "a": "",  # TU RESPUESTA AQUÍ
    "b": "",  # TU RESPUESTA AQUÍ
    "c": "",  # TU RESPUESTA AQUÍ
    "d": ""   # TU RESPUESTA AQUÍ
}

print("Tus respuestas:", respuesta_1_1)

# %% [markdown]
# ### Pregunta 1.2 (5 puntos)
#
# **¿Cuál es la salida de este código?**
#
# ```python
# x = [1, 2, 3, 4, 5]
# print(x[2])
# ```
#
# a) 1
# b) 2
# c) 3
# d) 4

# %%
# Marca tu respuesta (ejemplo: "a", "b", "c", o "d")
respuesta_1_2 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_1_2)

# %% [markdown]
# ### Pregunta 1.3 (5 puntos)
#
# **Completa el código para calcular el promedio de una lista:**

# %%
calificaciones = [85, 90, 78, 92, 88]

# Completa estas líneas
suma =   # COMPLETA AQUÍ: Usa sum()
cantidad =   # COMPLETA AQUÍ: Usa len()
promedio =   # COMPLETA AQUÍ: División

print(f"El promedio es: {promedio}")

# El resultado correcto debe ser 86.6

# %% [markdown]
# ### Pregunta 1.4 (5 puntos)
#
# **¿Qué hace este código?**
#
# ```python
# for i in range(5):
#     print(i * 2)
# ```
#
# a) Imprime números del 0 al 5
# b) Imprime números pares del 0 al 8
# c) Imprime números impares del 1 al 9
# d) Da un error

# %%
respuesta_1_4 = ""  # TU RESPUESTA AQUÍ (a, b, c, o d)

print("Tu respuesta:", respuesta_1_4)

# %% [markdown]
# ### Pregunta 1.5 (5 puntos)
#
# **Escribe una función que tome un número y devuelva si es par o impar:**

# %%
def es_par(numero):
    """
    Determina si un número es par o impar.
    
    Parameters:
    -----------
    numero : int
        Número a evaluar
    
    Returns:
    --------
    str
        "Par" o "Impar"
    """
    # TU CÓDIGO AQUÍ
    # Pista: Usa el operador módulo (%) para verificar si numero % 2 == 0
    
    pass

# Prueba tu función
print(es_par(10))  # Debería imprimir "Par"
print(es_par(7))   # Debería imprimir "Impar"

# %% [markdown]
# ---
#
# ## Sección 2: Ambientes de Desarrollo (15 puntos)
#
# ### Pregunta 2.1 (5 puntos)
#
# **¿Qué es Google Colab?**
#
# a) Una librería de Python para gráficos
# b) Un entorno de Jupyter Notebooks en la nube
# c) Un editor de texto para programar
# d) Una red social para programadores

# %%
respuesta_2_1 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_2_1)

# %% [markdown]
# ### Pregunta 2.2 (5 puntos)
#
# **¿Para qué sirve un ambiente virtual en Python?**
#
# a) Para ejecutar código más rápido
# b) Para aislar dependencias de diferentes proyectos
# c) Para compartir código con otros
# d) Para guardar archivos en la nube

# %%
respuesta_2_2 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_2_2)

# %% [markdown]
# ### Pregunta 2.3 (5 puntos)
#
# **¿Cuál es la diferencia entre un Jupyter Notebook (.ipynb) y un script Python (.py)?**
#
# Marca TODAS las opciones correctas:

# %%
# Marca True o False para cada afirmación
respuesta_2_3 = {
    "a_notebooks_permiten_ejecutar_celdas_individuales": None,  # True o False
    "b_notebooks_pueden_incluir_texto_y_ecuaciones": None,  # True o False
    "c_scripts_py_son_mejores_para_produccion": None,  # True o False
    "d_notebooks_no_pueden_importar_librerias": None   # True o False
}

print("Tus respuestas:", respuesta_2_3)

# %% [markdown]
# ---
#
# ## Sección 3: Inteligencia Artificial Generativa (20 puntos)
#
# ### Pregunta 3.1 (5 puntos)
#
# **¿Cuál es la diferencia principal entre ChatGPT, Gemini y Claude?**
#
# a) Todos son idénticos
# b) Son desarrollados por diferentes empresas y tienen fortalezas distintas
# c) Solo ChatGPT puede generar código
# d) Gemini es el único gratuito

# %%
respuesta_3_1 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_3_1)

# %% [markdown]
# ### Pregunta 3.2 (5 puntos)
#
# **¿Cuál de estos usos de IA es APROPIADO para tareas académicas?**
#
# a) Pedirle a la IA que haga todo el workshop completo
# b) Copiar código de la IA sin entenderlo
# c) Pedirle que explique un concepto que no entiendes
# d) Generar toda tu reflexión MEAL sin modificarla

# %%
respuesta_3_2 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_3_2)

# %% [markdown]
# ### Pregunta 3.3 (5 puntos)
#
# **¿Qué es una "alucinación" en el contexto de IA generativa?**
#
# a) Un error de sintaxis en el código
# b) Cuando la IA genera información falsa que suena verdadera
# c) Cuando el modelo es muy creativo
# d) Un tipo de visualización de datos

# %%
respuesta_3_3 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_3_3)

# %% [markdown]
# ### Pregunta 3.4 (5 puntos)
#
# **Escribe un prompt efectivo para que la IA te ayude a aprender (no a hacer el trabajo por ti):**
#
# **Escenario:** Tienes un error en tu código de Python que no entiendes.

# %% [markdown]
# **TU PROMPT AQUÍ:**
#
# [Escribe aquí tu prompt ideal - será evaluado por claridad y enfoque en aprendizaje]

# %% [markdown]
# ---
#
# ## Sección 4: GitHub (15 puntos)
#
# ### Pregunta 4.1 (5 puntos)
#
# **¿Qué es un "repositorio" en GitHub?**
#
# a) Un tipo de variable en Python
# b) Una carpeta que contiene un proyecto con historial de cambios
# c) Un servidor donde se ejecuta código
# d) Una base de datos

# %%
respuesta_4_1 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_4_1)

# %% [markdown]
# ### Pregunta 4.2 (5 puntos)
#
# **¿Qué comando usarías para copiar un repositorio de GitHub a tu computadora?**
#
# a) `git push`
# b) `git pull`
# c) `git clone`
# d) `git commit`

# %%
respuesta_4_2 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_4_2)

# %% [markdown]
# ### Pregunta 4.3 (5 puntos)
#
# **Ordena estos pasos para contribuir a un proyecto en GitHub:**
#
# 1. Hacer cambios en el código
# 2. Clonar el repositorio
# 3. Hacer commit de los cambios
# 4. Push al repositorio remoto
#
# ¿Cuál es el orden correcto?
#
# a) 2, 1, 3, 4
# b) 1, 2, 3, 4
# c) 2, 3, 1, 4
# d) 4, 3, 2, 1

# %%
respuesta_4_3 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_4_3)

# %% [markdown]
# ---
#
# ## Sección 5: Glosario y Conceptos (15 puntos)
#
# ### Pregunta 5.1 (5 puntos)
#
# **Relaciona cada término con su definición:**

# %%
# Relaciona cada término (clave) con su número de definición (valor)
# Definiciones:
# 1: Colección de código preescrito reutilizable
# 2: Valor numérico calculado de una muestra de datos
# 3: Interfaz que permite comunicación entre programas
# 4: Unidad básica de código que realiza una tarea específica

respuesta_5_1 = {
    "API": None,      # TU RESPUESTA: 1, 2, 3, o 4
    "Librería": None, # TU RESPUESTA: 1, 2, 3, o 4
    "Función": None,  # TU RESPUESTA: 1, 2, 3, o 4
    "Estadístico": None  # TU RESPUESTA: 1, 2, 3, o 4
}

print("Tus respuestas:", respuesta_5_1)

# %% [markdown]
# ### Pregunta 5.2 (5 puntos)
#
# **¿Qué es un "p-value" en estadística?**
#
# a) El valor promedio de los datos
# b) La probabilidad de obtener resultados observados si la hipótesis nula es cierta
# c) El porcentaje de datos válidos
# d) El valor máximo en un dataset

# %%
respuesta_5_2 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_5_2)

# %% [markdown]
# ### Pregunta 5.3 (5 puntos)
#
# **¿Qué significa "EDA" en Data Science?**
#
# a) Error Data Analysis
# b) Exploratory Data Analysis
# c) Estimated Data Algorithm
# d) External Database Access

# %%
respuesta_5_3 = ""  # TU RESPUESTA AQUÍ

print("Tu respuesta:", respuesta_5_3)

# %% [markdown]
# ---
#
# ## Sección 6: Práctica Integradora (10 puntos)
#
# ### Pregunta 6.1 (10 puntos)
#
# **Escenario Real:** Tienes un dataset de calificaciones de estudiantes y quieres analizar el promedio por materia.
#
# **Completa el código para:**
# 1. Importar pandas
# 2. Crear un DataFrame con los datos
# 3. Calcular el promedio por materia
# 4. Imprimir los resultados

# %%
# Paso 1: Importar pandas
# TU CÓDIGO AQUÍ


# Datos de ejemplo
datos = {
    'Estudiante': ['Ana', 'Luis', 'María', 'Pedro', 'Sofia'],
    'Matemáticas': [85, 90, 78, 92, 88],
    'Estadística': [88, 85, 92, 78, 90],
    'Programación': [90, 88, 85, 95, 87]
}

# Paso 2: Crear DataFrame
# TU CÓDIGO AQUÍ
df = 

# Paso 3: Calcular promedio por materia (columnas numéricas)
# TU CÓDIGO AQUÍ
promedios = 

# Paso 4: Imprimir resultados
print("Promedios por materia:")
print(promedios)

# %% [markdown]
# ---
#
# ## 📊 Autoevaluación Automática
#
# ### Ejecuta esta celda para ver tus resultados:

# %%
# Sistema de autoevaluación

# RESPUESTAS CORRECTAS (No mires antes de terminar!)
respuestas_correctas = {
    "1.1": {"a": "string", "b": "int", "c": "float", "d": "boolean"},
    "1.2": "c",
    "1.4": "b",
    "2.1": "b",
    "2.2": "b",
    "2.3": {"a_notebooks_permiten_ejecutar_celdas_individuales": True,
            "b_notebooks_pueden_incluir_texto_y_ecuaciones": True,
            "c_scripts_py_son_mejores_para_produccion": True,
            "d_notebooks_no_pueden_importar_librerias": False},
    "3.1": "b",
    "3.2": "c",
    "3.3": "b",
    "4.1": "b",
    "4.2": "c",
    "4.3": "a",
    "5.1": {"API": 3, "Librería": 1, "Función": 4, "Estadístico": 2},
    "5.2": "b",
    "5.3": "b"
}

# Función de evaluación
def evaluar_quiz():
    puntaje_total = 0
    puntaje_maximo = 90  # 10 puntos de la pregunta 6.1 son manuales
    
    print("="*70)
    print("📊 RESULTADOS DEL QUIZ DIAGNÓSTICO")
    print("="*70)
    print("\n")
    
    # Evaluar sección por sección
    resultados = {}
    
    # Sección 1: Python Básico (25 puntos)
    pts_seccion1 = 0
    if respuesta_1_1 == respuestas_correctas["1.1"]:
        pts_seccion1 += 5
    if respuesta_1_2 == respuestas_correctas["1.2"]:
        pts_seccion1 += 5
    # 1.3 y 1.5 son manuales
    if respuesta_1_4 == respuestas_correctas["1.4"]:
        pts_seccion1 += 5
    
    puntaje_total += pts_seccion1
    print(f"Sección 1 - Python Básico: {pts_seccion1}/15 puntos (15 automáticos, 10 manuales)")
    
    # Sección 2: Ambientes (15 puntos)
    pts_seccion2 = 0
    if respuesta_2_1 == respuestas_correctas["2.1"]:
        pts_seccion2 += 5
    if respuesta_2_2 == respuestas_correctas["2.2"]:
        pts_seccion2 += 5
    if respuesta_2_3 == respuestas_correctas["2.3"]:
        pts_seccion2 += 5
    
    puntaje_total += pts_seccion2
    print(f"Sección 2 - Ambientes de Desarrollo: {pts_seccion2}/15 puntos")
    
    # Sección 3: IA (20 puntos)
    pts_seccion3 = 0
    if respuesta_3_1 == respuestas_correctas["3.1"]:
        pts_seccion3 += 5
    if respuesta_3_2 == respuestas_correctas["3.2"]:
        pts_seccion3 += 5
    if respuesta_3_3 == respuestas_correctas["3.3"]:
        pts_seccion3 += 5
    # 3.4 es manual
    
    puntaje_total += pts_seccion3
    print(f"Sección 3 - IA Generativa: {pts_seccion3}/15 puntos (15 automáticos, 5 manuales)")
    
    # Sección 4: GitHub (15 puntos)
    pts_seccion4 = 0
    if respuesta_4_1 == respuestas_correctas["4.1"]:
        pts_seccion4 += 5
    if respuesta_4_2 == respuestas_correctas["4.2"]:
        pts_seccion4 += 5
    if respuesta_4_3 == respuestas_correctas["4.3"]:
        pts_seccion4 += 5
    
    puntaje_total += pts_seccion4
    print(f"Sección 4 - GitHub: {pts_seccion4}/15 puntos")
    
    # Sección 5: Glosario (15 puntos)
    pts_seccion5 = 0
    if respuesta_5_1 == respuestas_correctas["5.1"]:
        pts_seccion5 += 5
    if respuesta_5_2 == respuestas_correctas["5.2"]:
        pts_seccion5 += 5
    if respuesta_5_3 == respuestas_correctas["5.3"]:
        pts_seccion5 += 5
    
    puntaje_total += pts_seccion5
    print(f"Sección 5 - Glosario: {pts_seccion5}/15 puntos")
    
    print(f"\nSección 6 - Práctica Integradora: Evaluar manualmente (10 puntos)")
    
    # Puntaje total
    print("\n" + "="*70)
    print(f"PUNTAJE TOTAL (automático): {puntaje_total}/{puntaje_maximo} puntos")
    porcentaje = (puntaje_total / puntaje_maximo) * 100
    print(f"Porcentaje: {porcentaje:.1f}%")
    print("\nNotas:")
    print("- Faltan 25 puntos de preguntas manuales (1.3, 1.5, 3.4, 6.1)")
    print("- Puntaje máximo total: 100 puntos")
    print("="*70)
    
    # Interpretación
    print("\n📈 INTERPRETACIÓN:\n")
    if porcentaje >= 80:
        print("✅ EXCELENTE - Tienes una base sólida. Estás listo para el curso.")
        print("   Enfócate en reforzar las áreas con menor puntaje.")
    elif porcentaje >= 60:
        print("✅ BUENO - Tienes conocimientos básicos. Con práctica estarás al nivel.")
        print("   Recomendación: Revisa los temas donde obtuviste menor puntaje.")
    elif porcentaje >= 40:
        print("⚠️  REGULAR - Necesitas reforzar varios conceptos.")
        print("   Recomendación: Dedica tiempo extra a las secciones con menor puntaje.")
        print("   Recursos: Ver notebook de introducción y practicar ejemplos.")
    else:
        print("⚠️  NECESITAS APOYO - Muchos conceptos son nuevos para ti.")
        print("   Recomendación: No te preocupes, ¡para eso está el curso!")
        print("   Acción: Dedica 2-3 horas extra a la Semana 0 antes de continuar.")
        print("   Recursos: Tutorial de Python en notebook de introducción.")
    
    # Recomendaciones específicas
    print("\n🎯 ÁREAS PARA REFORZAR:\n")
    if pts_seccion1 < 10:
        print("- 🐍 Python Básico: Practica sintaxis, loops y funciones")
        print("  Recurso: https://www.learnpython.org/")
    if pts_seccion2 < 10:
        print("- 💻 Ambientes: Familiarízate con Google Colab y Jupyter")
        print("  Recurso: https://colab.research.google.com/")
    if pts_seccion3 < 10:
        print("- 🤖 IA Generativa: Aprende sobre uso ético y efectivo")
        print("  Recurso: https://www.promptingguide.ai/")
    if pts_seccion4 < 10:
        print("- 🐙 GitHub: Practica clonar repos y comandos básicos")
        print("  Recurso: https://skills.github.com/")
    if pts_seccion5 < 10:
        print("- 📖 Glosario: Revisa términos técnicos en notebook intro")
    
    print("\n" + "="*70)
    print("💡 SIGUIENTE PASO: Comparte estos resultados con tu profesor")
    print("   para recibir orientación personalizada.")
    print("="*70)

# Ejecutar evaluación
evaluar_quiz()

# %% [markdown]
# ---
#
# ## 📝 Reflexión Personal
#
# **Después de completar el quiz, responde:**
#
# ### 1. ¿Qué área te resultó más difícil?
#
# [TU RESPUESTA AQUÍ]
#
# ### 2. ¿Qué área ya dominas?
#
# [TU RESPUESTA AQUÍ]
#
# ### 3. ¿Qué acciones tomarás para prepararte mejor?
#
# [TU RESPUESTA AQUÍ]
#
# ### 4. ¿Tienes alguna pregunta para el profesor?
#
# [TU RESPUESTA AQUÍ]
#
# ---
#
# ## 🚀 Próximos Pasos
#
# Basándote en tus resultados:
#
# **Si obtuviste >80%:**
# - ✅ Estás listo para Semana 1
# - Repasa brevemente las áreas con menor puntaje
#
# **Si obtuviste 60-80%:**
# - 📚 Dedica 2-3 horas a revisar conceptos clave
# - Practica con los ejercicios del notebook de introducción
# - Consulta recursos recomendados
#
# **Si obtuviste <60%:**
# - 📖 Dedica una semana adicional a la Semana 0
# - Trabaja todos los tutoriales recomendados
# - Agenda una sesión con el profesor o tutor
# - No te desanimes, ¡todos empezamos desde algún lugar!
#
# ---
#
# ## 📚 Recursos Recomendados por Área
#
# ### Python Básico:
# - [Python.org Tutorial](https://docs.python.org/es/3/tutorial/)
# - [Kaggle - Python](https://www.kaggle.com/learn/python)
# - [Real Python - Basics](https://realpython.com/tutorials/basics/)
#
# ### Google Colab:
# - [Colab Welcome Notebook](https://colab.research.google.com/notebooks/intro.ipynb)
# - [Colab FAQ](https://research.google.com/colaboratory/faq.html)
#
# ### IA Generativa:
# - [Prompt Engineering Guide](https://www.promptingguide.ai/)
# - [Learn Prompting](https://learnprompting.org/)
#
# ### GitHub:
# - [GitHub Skills](https://skills.github.com/)
# - [Learn Git Branching](https://learngitbranching.js.org/)
#
# ---
#
# **¡Felicidades por completar el quiz diagnóstico!** 🎉
#
# Recuerda: Este quiz es solo el punto de partida. El aprendizaje real ocurre durante el curso. ¡Vamos juntos en este viaje! 🚀

# %% [markdown]
# <a href="https://colab.research.google.com/github/HesusG/diagnostico-lineas-accion/blob/main/Semana1/ejercicios_extra/practica_ong_estadistica_basica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏥 Práctica Extra: Fundación Esperanza - Análisis de Retención de Donadores
#
# **Curso:** CD2001B - Diagnóstico para Líneas de Acción
# **Módulo:** 1 - Estadística Básica para Negocios
# **Tipo:** Ejercicio de práctica adicional
# **Dataset:** fundacion_esperanza_donadores.csv
# **Tiempo estimado:** 90-120 minutos
#
# ---
#
# ## 🎯 Objetivo de Aprendizaje
#
# Aplicar técnicas de **estadística descriptiva e inferencial** para analizar factores que influyen en la retención de donadores de una ONG, incluyendo:
#
# - Análisis exploratorio de datos
# - Medidas de tendencia central y dispersión
# - Visualizaciones efectivas
# - Pruebas de hipótesis (t de una muestra, t de dos muestras independientes)
# - Interpretación de resultados en contexto de negocio
# - Reflexión MEAL (Monitoring, Evaluation, Accountability and Learning)
#
# ---
#
# ## 📖 Contexto del Caso
#
# **Organización:** Fundación Esperanza
# **Misión:** ONG dedicada a la rehabilitación y salud infantil (similar a Teletón)
# **Ubicación:** América Latina
#
# ### Situación
#
# La Fundación Esperanza ha experimentado una **tasa de retención de donadores del 40%** en el último año. El departamento de Desarrollo desea entender:
#
# 1. **¿Qué factores diferencian a donadores retenidos vs no retenidos?**
# 2. **¿Los niveles de confianza y satisfacción están por encima de umbrales aceptables?**
# 3. **¿El voluntariado fortalece la conexión emocional con la misión?**
#
# Como **analista de datos**, tu tarea es:
# - Explorar el dataset de 1000 donadores
# - Realizar pruebas estadísticas para responder preguntas clave
# - Proveer recomendaciones basadas en datos
#
# ### Dataset
#
# El dataset contiene información de **1000 donadores** recopilada mediante encuesta anual, con **26 variables**:
#
# **Variables clave para este ejercicio:**
#
# - **Demográficas:** edad_categoria, nivel_educacion, rango_ingreso
# - **Comportamiento:** tipo_donante, frecuencia_donacion, voluntariado, años_como_donante
# - **Escalas Likert 1-10:**
#   - **Confianza:** confianza_financiera, confianza_mision, confianza_transparencia
#   - **Satisfacción:** satisfaccion_general, satisfaccion_comunicacion, satisfaccion_impacto
#   - **Engagement:** conexion_emocional, compromiso_futuro
# - **Target:** donara_proximo_año (Sí/No)
#
# 📚 **Nota:** Para descripción completa de variables, consulta `CODEBOOK_fundacion_esperanza.md`
#
# ---

# %% [markdown]
# ## Parte 1: Configuración y Carga de Datos (5 puntos)
#
# ### 1.1 Importar Librerías

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de visualizaciones
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
# %matplotlib inline

print("✅ Librerías importadas exitosamente")

# %% [markdown]
# ### 1.2 Cargar Dataset

# %%
# Cargar dataset desde la carpeta de datos
# Si estás en Colab, descarga primero el archivo desde el repositorio

# Opción 1: Desde archivo local (si descargaste el repo)
df = pd.read_csv('https://raw.githubusercontent.com/HesusG/diagnostico-lineas-accion/main/Semana1/datos/fundacion_esperanza_donadores.csv')

# Opción 2: Desde GitHub (si estás en Colab)
# df = pd.read_csv('https://raw.githubusercontent.com/HesusG/diagnostico-lineas-accion/main/Semana1/datos/fundacion_esperanza_donadores.csv')

print(f"📊 Dataset cargado: {df.shape[0]} filas × {df.shape[1]} columnas")
print(f"\n🔍 Primeras 5 filas:")
df.head()

# %% [markdown]
# ### 1.3 Inspección Inicial
#
# **Instrucciones:** Completa el código para inspeccionar el dataset.

# %%
# Información general del dataset
print("ℹ️ Información del Dataset:")
df.info()

print("\n" + "="*70)
print("❓ Verificar Valores Faltantes:")
# TU CÓDIGO AQUÍ: Usa df.isnull().sum() para contar valores faltantes


print("\n" + "="*70)
print("🔢 Estadísticas Descriptivas (variables numéricas):")
# TU CÓDIGO AQUÍ: Usa df.describe() para ver estadísticas descriptivas

# %% [markdown]
# **📝 Pregunta 1.1 (5 puntos):** Basándote en la inspección:
# - ¿Hay valores faltantes en el dataset?
# - ¿Cuántas variables categóricas hay?
# - ¿Cuántas variables numéricas (Likert 1-10) hay?
#
# *Escribe tu respuesta en la celda siguiente (doble clic para editar):*

# %% [markdown]
# **RESPUESTA:**
#
# - Valores faltantes: [TU RESPUESTA]
# - Variables categóricas: [TU RESPUESTA]
# - Variables numéricas Likert: [TU RESPUESTA]

# %% [markdown]
# ---
#
# ## Parte 2: Análisis Descriptivo (25 puntos)
#
# ### 2.1 Distribución de la Variable Objetivo
#
# Analicemos la variable target `donara_proximo_año` (retención de donadores).

# %%
# Tabla de frecuencias de la variable objetivo
print("🎯 VARIABLE OBJETIVO: donara_proximo_año\n")

# TU CÓDIGO AQUÍ: Calcula frecuencias absolutas y porcentajes
# Sugerencia: Usa df['donara_proximo_año'].value_counts() y .value_counts(normalize=True)

frecuencias = 
porcentajes = 

print("Frecuencias Absolutas:")
print(frecuencias)
print("\nPorcentajes:")
print(porcentajes)

# Crear gráfico de barras
plt.figure(figsize=(8, 5))
# TU CÓDIGO AQUÍ: Crea un gráfico de barras de la variable objetivo
# Sugerencia: Usa sns.countplot() o .plot(kind='bar')


plt.title('Distribución de Retención de Donadores', fontsize=14, fontweight='bold')
plt.xlabel('¿Donará próximo año?')
plt.ylabel('Número de Donadores')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Pregunta 2.1 (5 puntos):** ¿Cuál es la tasa de retención actual? ¿Consideras que es alta, media o baja? Justifica tu respuesta.
#
# *Escribe tu respuesta aquí:*

# %% [markdown]
# **RESPUESTA:**
#
# [TU RESPUESTA AQUÍ]

# %% [markdown]
# ### 2.2 Análisis de Variables Numéricas Clave
#
# Analicemos las variables de **confianza**, **satisfacción** y **engagement**.

# %%
# Definir variables de interés (escalas Likert 1-10)
likert_vars = [
    'confianza_financiera',
    'confianza_mision',
    'satisfaccion_general',
    'satisfaccion_comunicacion',
    'conexion_emocional',
    'compromiso_futuro'
]

# TU CÓDIGO AQUÍ: Calcula estadísticas descriptivas para estas variables
# Sugerencia: Usa df[likert_vars].describe().T para transponer y ver mejor

print("📊 ESTADÍSTICAS DESCRIPTIVAS - Variables Likert 1-10\n")
estadisticas = 

# Agregar moda manualmente
# TU CÓDIGO AQUÍ: Calcula la moda para cada variable
# Sugerencia: Usa df[likert_vars].mode().iloc[0]


estadisticas

# %% [markdown]
# **📝 Pregunta 2.2 (10 puntos):**
#
# a) ¿Cuál variable tiene la media más alta? ¿Y la más baja?
#
# b) ¿Cuál variable tiene mayor dispersión (mayor desviación estándar)?
#
# c) ¿Qué te dicen estos resultados sobre el desempeño de la Fundación?
#
# *Escribe tus respuestas aquí:*

# %% [markdown]
# **RESPUESTA:**
#
# a) [TU RESPUESTA]
#
# b) [TU RESPUESTA]
#
# c) [TU RESPUESTA]

# %% [markdown]
# ### 2.3 Visualizaciones Exploratorias
#
# Creemos un **dashboard de visualizaciones** para explorar las distribuciones.

# %%
# Dashboard de 6 gráficos: histogramas de variables Likert
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# TU CÓDIGO AQUÍ: Crea histogramas para cada variable en likert_vars
# Sugerencia: Usa un loop for con enumerate(likert_vars)
# Dentro del loop: axes[i].hist(df[var], bins=10, edgecolor='black', alpha=0.7)

for i, var in enumerate(likert_vars):
    # TU CÓDIGO AQUÍ
    
    
    
    axes[i].set_xlabel('Calificación (1-10)', fontsize=10)
    axes[i].set_ylabel('Frecuencia', fontsize=10)
    axes[i].set_title(f'{var.replace("_", " ").title()}', fontsize=11, fontweight='bold')
    axes[i].grid(axis='y', alpha=0.3)

plt.suptitle('Distribuciones de Variables Likert (1-10)', fontsize=14, fontweight='bold', y=1.00)
plt.tight_layout()
plt.show()

# %% [markdown]
# **📝 Pregunta 2.3 (10 puntos):**
#
# Observa las distribuciones:
#
# a) ¿Cuáles variables tienen distribuciones aproximadamente simétricas?
#
# b) ¿Hay alguna variable con sesgo hacia calificaciones altas o bajas?
#
# c) ¿Qué implicaciones tienen estos patrones para la Fundación?
#
# *Escribe tus observaciones aquí:*

# %% [markdown]
# **RESPUESTA:**
#
# a) [TU RESPUESTA]
#
# b) [TU RESPUESTA]
#
# c) [TU RESPUESTA]

# %% [markdown]
# ---
#
# ## Parte 3: Pruebas de Hipótesis (50 puntos)
#
# ### 3.1 Prueba t de Una Muestra (15 puntos)
#
# **Contexto:** La Fundación Esperanza establece como **umbral mínimo aceptable** una calificación de **7.0** en `confianza_financiera` (manejo responsable de fondos).
#
# **Pregunta de Negocio:** ¿La confianza financiera promedio de los donadores está por debajo del umbral aceptable?
#
# ---
#
# #### Paso 1: Plantear Hipótesis

# %% [markdown]
# **📝 Ejercicio 3.1a (5 puntos):** Escribe las hipótesis nula y alternativa.
#
# **Hipótesis:**
#
# - **H₀ (Nula):** [TU RESPUESTA - ¿Qué afirma la hipótesis nula sobre μ?]
#
# - **H₁ (Alternativa):** [TU RESPUESTA - ¿Qué afirma la hipótesis alternativa?]
#
# **Tipo de prueba:** [¿Es unilateral izquierda, unilateral derecha, o bilateral?]
#
# **Nivel de significancia:** α = 0.05

# %% [markdown]
# #### Paso 2: Exploración Descriptiva

# %%
# Estadísticas descriptivas de confianza_financiera
variable = df['confianza_financiera']

# TU CÓDIGO AQUÍ: Calcula media, desviación estándar, n
media_obs = 
desv_est = 
n = 

print("📊 ESTADÍSTICAS DESCRIPTIVAS: confianza_financiera\n")
print(f"Media observada: {media_obs:.3f}")
print(f"Desviación estándar: {desv_est:.3f}")
print(f"Tamaño de muestra: {n}")
print(f"Valor de referencia: 7.0")
print(f"Diferencia: {media_obs - 7.0:.3f}")

# %% [markdown]
# #### Paso 3: Realizar Prueba t de Una Muestra

# %%
# TU CÓDIGO AQUÍ: Realiza la prueba t de una muestra
# Sugerencia: Usa stats.ttest_1samp(variable, popmean=7.0, alternative='less')
# Nota: alternative='less' porque queremos probar si la media es MENOR que 7.0

t_stat, p_value = 

print("\n" + "="*70)
print("🧪 RESULTADOS DE LA PRUEBA T DE UNA MUESTRA\n")
print(f"Estadístico t: {t_stat:.4f}")
print(f"Valor p (unilateral): {p_value:.4f}")
print(f"Nivel de significancia α: 0.05")
print("="*70)

# %% [markdown]
# #### Paso 4: Decisión e Interpretación

# %%
# TU CÓDIGO AQUÍ: Escribe la lógica de decisión
alpha = 0.05

if p_value < alpha:
    decision = "Rechazamos H₀"
    conclusion = "Hay evidencia estadística suficiente para afirmar que la confianza financiera promedio es MENOR que 7.0"
else:
    decision = "No rechazamos H₀"
    conclusion = "No hay evidencia estadística suficiente para afirmar que la confianza financiera promedio es menor que 7.0"

print("\n📋 DECISIÓN ESTADÍSTICA:\n")
print(f"Decisión: {decision}")
print(f"\nConclusión: {conclusion}")

# %% [markdown]
# **📝 Pregunta 3.1b (10 puntos):**
#
# Responde las siguientes preguntas sobre la prueba:
#
# a) **Interpretación en contexto de negocio:** ¿Qué significa este resultado para la Fundación Esperanza? ¿Deberían preocuparse por los niveles de confianza financiera?
#
# b) **Recomendación:** ¿Qué acciones concretas sugieres basándote en este resultado?
#
# *Escribe tus respuestas aquí:*

# %% [markdown]
# **RESPUESTA:**
#
# a) **Interpretación en contexto:**
#
# [TU RESPUESTA]
#
# b) **Recomendación:**
#
# [TU RESPUESTA]

# %% [markdown]
# ---
#
# ### 3.2 Prueba t de Dos Muestras Independientes (20 puntos)
#
# **Contexto:** La Fundación cree que los **voluntarios** (quienes participan activamente en actividades de la ONG) tienen mayor **conexión emocional** con la misión que los no voluntarios.
#
# **Pregunta de Negocio:** ¿Los voluntarios tienen mayor conexión emocional que los no voluntarios?
#
# ---
#
# #### Paso 1: Plantear Hipótesis

# %% [markdown]
# **📝 Ejercicio 3.2a (5 puntos):** Escribe las hipótesis.
#
# **Hipótesis:**
#
# - **H₀ (Nula):** [TU RESPUESTA - ¿Qué afirma sobre μ_voluntarios y μ_no_voluntarios?]
#
# - **H₁ (Alternativa):** [TU RESPUESTA]
#
# **Tipo de prueba:** [¿Unilateral o bilateral?]
#
# **Nivel de significancia:** α = 0.05

# %% [markdown]
# #### Paso 2: Exploración Descriptiva por Grupos

# %%
# TU CÓDIGO AQUÍ: Calcula estadísticas descriptivas por grupo
# Sugerencia: Usa df.groupby('voluntariado')['conexion_emocional'].agg(['mean', 'std', 'count'])

print("📊 ESTADÍSTICAS DESCRIPTIVAS POR GRUPO\n")
print("Variable: conexion_emocional (escala 1-10)")
print("Grupos: Voluntariado (Sí / No)\n")

stats_by_group = 
print(stats_by_group)

# Visualización: Boxplot comparativo
plt.figure(figsize=(10, 6))
# TU CÓDIGO AQUÍ: Crea un boxplot de conexion_emocional por voluntariado
# Sugerencia: Usa sns.boxplot(data=df, x='voluntariado', y='conexion_emocional')


plt.title('Comparación de Conexión Emocional: Voluntarios vs No Voluntarios', fontsize=14, fontweight='bold')
plt.xlabel('¿Participa como Voluntario?', fontsize=12)
plt.ylabel('Conexión Emocional (1-10)', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Paso 3: Verificar Supuestos (Opcional pero Recomendado)
#
# Antes de realizar la prueba t, idealmente deberíamos verificar:
# 1. **Normalidad** de cada grupo (Shapiro-Wilk test)
# 2. **Homogeneidad de varianzas** (Levene's test)
#
# Para fines didácticos, asumiremos que se cumplen los supuestos.

# %% [markdown]
# #### Paso 4: Realizar Prueba t de Dos Muestras

# %%
# Separar datos por grupo
# TU CÓDIGO AQUÍ: Crea dos arrays con los datos de cada grupo
# Sugerencia: grupo_voluntarios = df[df['voluntariado'] == 'Sí']['conexion_emocional']

grupo_voluntarios = 
grupo_no_voluntarios = 

print(f"Tamaño grupo voluntarios: {len(grupo_voluntarios)}")
print(f"Tamaño grupo no voluntarios: {len(grupo_no_voluntarios)}")

# TU CÓDIGO AQUÍ: Realiza la prueba t de dos muestras independientes
# Sugerencia: stats.ttest_ind(grupo_voluntarios, grupo_no_voluntarios, alternative='greater')
# Nota: alternative='greater' porque queremos probar si voluntarios > no_voluntarios

t_stat, p_value = 

print("\n" + "="*70)
print("🧪 RESULTADOS DE LA PRUEBA T DE DOS MUESTRAS\n")
print(f"Estadístico t: {t_stat:.4f}")
print(f"Valor p (unilateral): {p_value:.4f}")
print(f"Nivel de significancia α: 0.05")
print("="*70)

# %% [markdown]
# #### Paso 5: Decisión e Interpretación

# %%
# TU CÓDIGO AQUÍ: Escribe la lógica de decisión
alpha = 0.05

# TU CÓDIGO AQUÍ


print("\n📋 DECISIÓN ESTADÍSTICA:\n")
print(f"Decisión: {decision}")
print(f"\nConclusión: {conclusion}")

# Tamaño del efecto (Cohen's d)
mean_diff = grupo_voluntarios.mean() - grupo_no_voluntarios.mean()
pooled_std = np.sqrt(((len(grupo_voluntarios)-1)*grupo_voluntarios.std()**2 + 
                      (len(grupo_no_voluntarios)-1)*grupo_no_voluntarios.std()**2) / 
                     (len(grupo_voluntarios) + len(grupo_no_voluntarios) - 2))
cohens_d = mean_diff / pooled_std

print(f"\n📏 Tamaño del efecto (Cohen's d): {cohens_d:.3f}")
print("Interpretación: ", end="")
if abs(cohens_d) < 0.2:
    print("Efecto pequeño")
elif abs(cohens_d) < 0.5:
    print("Efecto pequeño-mediano")
elif abs(cohens_d) < 0.8:
    print("Efecto mediano")
else:
    print("Efecto grande")

# %% [markdown]
# **📝 Pregunta 3.2b (15 puntos):**
#
# a) **Interpretación en contexto:** ¿Qué significa este resultado para la estrategia de engagement de la Fundación?
#
# b) **Magnitud del efecto:** ¿El tamaño del efecto es práctico/significativo para la organización?
#
# c) **Recomendación estratégica:** ¿Qué acciones sugierEs para fortalecer la conexión emocional?
#
# *Escribe tus respuestas aquí:*

# %% [markdown]
# **RESPUESTA:**
#
# a) **Interpretación:**
#
# [TU RESPUESTA]
#
# b) **Magnitud:**
#
# [TU RESPUESTA]
#
# c) **Recomendación:**
#
# [TU RESPUESTA]

# %% [markdown]
# ---
#
# ### 3.3 Prueba t de Dos Muestras: Retención (15 puntos)
#
# **Contexto:** Queremos investigar si los **donadores retenidos** (donara_proximo_año = "Sí") tienen mayor **satisfacción general** que los no retenidos.
#
# **Pregunta de Negocio:** ¿La satisfacción general es mayor en donadores retenidos?
#
# ---
#
# **📝 Ejercicio 3.3 (15 puntos):** Realiza el análisis completo siguiendo los pasos anteriores:
#
# 1. Plantea hipótesis
# 2. Explora descriptivamente ambos grupos
# 3. Crea visualización comparativa (boxplot o violin plot)
# 4. Realiza prueba t de dos muestras
# 5. Interpreta resultados y provee recomendaciones

# %%
# TU CÓDIGO COMPLETO AQUÍ

print("🎯 ANÁLISIS: Satisfacción General por Retención\n")
print("Grupos: Retenidos (donara_proximo_año = Sí) vs No Retenidos (No)\n")
print("="*70)

# Paso 1: Hipótesis (escríbelas en comentarios)
# H₀: 
# H₁: 

# Paso 2: Exploración descriptiva
# TU CÓDIGO AQUÍ


# Paso 3: Visualización
# TU CÓDIGO AQUÍ


# Paso 4: Prueba t
# TU CÓDIGO AQUÍ


# Paso 5: Decisión e interpretación
# TU CÓDIGO AQUÍ

# %% [markdown]
# **Interpretación y Recomendaciones:**
#
# [ESCRIBE TU ANÁLISIS AQUÍ]

# %% [markdown]
# ---
#
# ## Parte 4: Reflexión MEAL (20 puntos)
#
# ### ¿Qué es MEAL?
#
# **MEAL** es un marco utilizado en organizaciones de desarrollo y ONGs para:
# - **M**onitoring (Monitoreo): Seguimiento continuo de actividades
# - **E**valuation (Evaluación): Análisis de resultados e impacto
# - **A**ccountability (Rendición de cuentas): Transparencia con stakeholders
# - **L**earning (Aprendizaje): Mejora continua basada en evidencia
#
# ---
#
# ### 4.1 Reflexión Individual
#
# **📝 Ejercicio 4.1 (20 puntos):** Redacta una reflexión MEAL estructurada (300-400 palabras) sobre el análisis realizado:
#
# **Estructura sugerida:**
#
# 1. **Monitoring (¿Qué medimos?):**
#    - Resume las variables analizadas
#    - Menciona los indicadores clave (medias, tasas, etc.)
#
# 2. **Evaluation (¿Qué encontramos?):**
#    - Resume hallazgos de las 3 pruebas de hipótesis
#    - Identifica patrones importantes
#    - Menciona fortalezas y áreas de mejora
#
# 3. **Accountability (¿A quién reportamos y qué recomendamos?):**
#    - ¿Qué le dirías a la Junta Directiva de la Fundación?
#    - ¿Qué acciones concretas recomiendas?
#    - ¿Qué riesgos existen si no se actúa?
#
# 4. **Learning (¿Qué aprendimos metodológicamente?):**
#    - ¿Qué técnicas estadísticas fueron más útiles?
#    - ¿Qué limitaciones tiene este análisis?
#    - ¿Qué análisis adicionales sugieres para el futuro?
#
# *Escribe tu reflexión en la celda siguiente:*

# %% [markdown]
# ### 📋 REFLEXIÓN MEAL: Análisis de Retención de Donadores - Fundación Esperanza
#
# **Autor:** [Tu nombre]
# **Fecha:** [Fecha]
# **Destinatario:** Dirección de Desarrollo y Junta Directiva
#
# ---
#
# #### 1. MONITORING (¿Qué medimos?)
#
# [ESCRIBE AQUÍ]
#
# ---
#
# #### 2. EVALUATION (¿Qué encontramos?)
#
# [ESCRIBE AQUÍ]
#
# ---
#
# #### 3. ACCOUNTABILITY (¿Qué recomendamos?)
#
# [ESCRIBE AQUÍ]
#
# ---
#
# #### 4. LEARNING (¿Qué aprendimos?)
#
# [ESCRIBE AQUÍ]
#
# ---
#
# **Conclusión:**
#
# [MENSAJE FINAL]

# %% [markdown]
# ---
#
# ## 📊 Resumen de Tareas Completadas
#
# **Marca con ✅ las tareas completadas:**
#
# - [ ] Parte 1: Carga y exploración inicial (5 pts)
# - [ ] Parte 2: Análisis descriptivo (25 pts)
#   - [ ] 2.1 Distribución de variable objetivo
#   - [ ] 2.2 Análisis de variables Likert
#   - [ ] 2.3 Visualizaciones exploratorias
# - [ ] Parte 3: Pruebas de hipótesis (50 pts)
#   - [ ] 3.1 Prueba t de una muestra (15 pts)
#   - [ ] 3.2 Prueba t dos muestras: voluntariado (20 pts)
#   - [ ] 3.3 Prueba t dos muestras: retención (15 pts)
# - [ ] Parte 4: Reflexión MEAL (20 pts)
#
# **Puntuación total:** ___ / 100 puntos
#
# ---
#
# ## 🎓 Autoevaluación
#
# Responde honestamente:
#
# 1. **¿Qué parte del análisis te resultó más desafiante?**
#
# [TU RESPUESTA]
#
# 2. **¿Qué concepto estadístico ahora comprendes mejor?**
#
# [TU RESPUESTA]
#
# 3. **¿Cómo aplicarías este flujo de análisis a otro contexto (ej: e-commerce, educación)?**
#
# [TU RESPUESTA]
#
# ---
#
# ## 🚀 Próximos Pasos
#
# **Para seguir practicando:**
#
# 1. **Explora otras variables:** Analiza `compromiso_futuro`, `percepcion_impacto`, etc.
# 2. **Compara otros grupos:** ¿Hay diferencias por `canal_donacion` o `tipo_donante`?
# 3. **Prepárate para Semana 2:** Próximamente verás chi-cuadrada, ANOVA y regresión lineal
# 4. **Consulta el CODEBOOK:** Lee `CODEBOOK_fundacion_esperanza.md` para entender mejor las variables
#
# ---
#
# ## 📚 Referencias Útiles
#
# **Dataset y Documentación:**
# - `CODEBOOK_fundacion_esperanza.md` - Descripción completa de variables
# - Workshop 1 - Medidas de Tendencia Central
# - Workshop 1 - Pruebas de Hipótesis 1 y 2 Muestras
#
# **Recursos Adicionales:**
# - scipy.stats documentation: https://docs.scipy.org/doc/scipy/reference/stats.html
# - Sargeant, A. (2001). Relationship Fundraising Theory
#
# ---
#
# **¡Excelente trabajo completando esta práctica!** 🎉
#
# *Este ejercicio te prepara para aplicar estadística inferencial a problemas reales de ONGs y organizaciones sociales.*
